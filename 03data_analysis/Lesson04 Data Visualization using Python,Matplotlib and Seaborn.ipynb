# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Line Chart

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples)

# %%
plt.plot(yield_apples);

# %% [markdown]
# ## Customizing the X-axis

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(years,yield_apples);

# %% [markdown]
# ## Axis Labels

# %%
plt.plot(years,yield_apples);
plt.xlabel('Year');
plt.ylabel('Yield (tons per hectare)');

# %% [markdown]
# ## Plotting Multiple Lines

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years,apples);
plt.plot(years,oranges);
plt.xlabel('Y ear');
plt.ylabel('Yield');

# %% [markdown]
# ## Chart title and Legend

# %%
plt.plot(years,apples);
plt.plot(years,oranges);
plt.xlabel('Y ear');
plt.ylabel('Yield');
plt.title('Crop Yield in Kanto');
plt.legend(['Apples','Oranges']);

# %% [markdown]
# ## Line Markers

# %%
plt.plot(years,apples,marker='o');
plt.plot(years,oranges,marker='x');
plt.xlabel('Y ear');
plt.ylabel('Yield');
plt.title('Crop Yield in Kanto');
plt.legend(['Apples','Oranges']);

# %% [markdown]
# ## Styling Lines and Markers

# %%
plt.plot(years,apples,marker='o',c='b',ls='-',lw=4,ms=8,mew=3,mec='g');
plt.plot(years,oranges,marker='x',c='r',ls='-',ms=10,alpha=.5);
plt.xlabel('Y ear');
plt.ylabel('Yield');
plt.title('Crop Yield in Kanto');
plt.legend(['Apples','Oranges']);

# %%
plt.plot(years,apples,'xg'); # 没有指定 ls（line style） 的话，就只有marker 被画出来   
plt.plot(years,oranges,'or',ls='-');

# %% [markdown]
# ## Changing the Figure Size

# %%
import matplotlib.pyplot as plt
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

plt.figure(figsize=(19.2, 10.8),dpi=100)# 默认figure是 6.4,4.8 ,dpi 默认是100
# 此时的像素大小是  1920x1080  
plt.plot(years, yield_apples, 'or');
plt.savefig('test.png');

# %% [markdown]
# ## Improving Default Styles using Seaborn

# %% [markdown]
# An easy way to make your charts look beautiful is to use some default styles from the Seaborn library. These can be applied globally using the sns.set_style function. You can see a full list of predefined styles here:
# https://seaborn.pydata.org/generated/seaborn.set_style.html .

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
# 没有使用 sns 时：
plt.plot(years,apples,'s-b');
plt.plot(years,oranges,'o--r');

# %%
# 使用 sns 改善
sns.set_style('whitegrid')
plt.plot(years,apples,'s-b');
plt.plot(years,oranges,'o--r');

# %%
# 使用 sns 改善
sns.set_style('darkgrid')
plt.plot(years,apples,'s-b');
plt.plot(years,oranges,'o--r');

# %% [markdown]
# # Scatter Plot

# %%
# Load data into a Pandas dataframe
import matplotlib.pyplot as plt
import seaborn as sns

flowers_df = sns.load_dataset('iris');

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# 可视化 sepal length 和 width 
plt.plot(flowers_df.sepal_length,flowers_df.sepal_width) # 效果不行

# %%
# 使用 sns.scatterplot() 散点图
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## Adding Hues（添加色调）

# %% [markdown]
# 我们用色调给不同花种上色，同时也把point size 调大

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width,hue=flowers_df.species,s=100) 
# s 参数是 point size
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# Adding hues makes the plot more informative. We can immediately tell that Setosa flowers have a smaller sepal length but higher sepal widths. In contrast, the opposite is true for Virginica flowers.

# %% [markdown]
# ## Customing Seaborn Figures

# %% [markdown]
# Since Seaborn uses Matplotlib's plotting functions internally, we can use functions like
#
# plt.figure
#
# and
#
# plt.title
#
# to modify the figure.

# %%
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimensions')

sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species,
                s=100);

# %% [markdown]
# ## Plotting using Pandas Data Frames

# %% [markdown]
# Seaborn has in-built support for Pandas data frames. Instead of passing each column as a series, you can provide column names and use the data argument to specify a data frame.

# %%
sns.scatterplot(x='sepal_length',
                y='sepal_width',
                hue='species',  # 以上三个字符串必须要和下面的data相符
                s=100,
                data = flowers_df,
               )
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # Histogram 直方图

# %%
flowers_df = sns.load_dataset('iris')

# %%
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of Sepal Width");
plt.hist(flowers_df.sepal_width); # default bins is 10

# %% [markdown]
# ## Controlling the size and number of bins

# %%
plt.title("Distribution of Sepal Width");
plt.hist(flowers_df.sepal_width,bins=5);# default bins is 10

# %% [markdown]
# 明确bins 的边界

# %%
import numpy as np

# %%
plt.hist(flowers_df.sepal_width,bins=np.arange(2,5,0.25));

# %% [markdown]
# ## Multiple Histograms

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
# 两种花的 width 一起画出来
plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));

# %%
plt.title('Distribution of Sepal Width')

plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         #stacked=True
        );

plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %% [markdown]
# We can also stack multiple histograms on top of one another.

# %%
plt.title('Distribution of Sepal Width')

plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True
        );

plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %% [markdown]
# # Bar Chart

# %% [markdown]
# Bar charts are quite similar to line charts, i.e., they show a sequence of values. However, a bar is shown for each value, rather than points connected by lines. We can use the plt.bar function to draw a bar chart.

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years,apples)
# Out:
# <BarContainer object of 6 artists>

# %%
years = np.arange(2000,2006)# the label locations
width = 0.35  # the width of the bars

plt.bar(years - width/2, apples, width, label='Apple')
plt.bar(years + width/2, oranges, width, label='Orange')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(years,apples);
plt.bar(years,oranges,bottom=apples);

# %% [markdown]
# # 关于ppi

# %%
# 我电脑的尺寸： 17.3寸
# 1寸  = 1.31 inch   1inch = 2.54 cm
# 所以我电脑的尺寸是:17.3*1.31 = 22.67inch 
# 又因为我的w:h 是 16:9 
# 所以width: 22.67 * 16/25=14.5inch  height: 22.67 * 9 /25=8.16inch
# 所以 width是 14.5 * 2.54 = 36.8 cm height：8.16* 2.54 = 20.7 cm   理论值！！！

# %%
# 对角线长是 17.3 = 17.3 * 2.54 = 43.9 cm
43.9**2
# Out:
# 1927.2099999999998

# %%
38**2 + 21**2  # 实际大概测量
# Out:
# 1885

# %%
38 / 21 # 约等于 16:9
# Out:
# 1.8095238095238095

# %%
# 我电脑的 ppi = sqrt(w^2 + h^2)/17.3
ppi = (1920**2 + 1080**2)**(1/2) / 17.3
ppi
# Out:
# 127.33567457123111

# %% [markdown]
# dpi :dots per inch  【1inch 上水滴的数量】
#
# ppi :pixels per inch 【1inch 上光点的数量】
